# %%
import tensorflow

# %%
from keras.layers import Dense, Conv2D, MaxPooling2D, Flatten
from keras.models import Sequential
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
cnn = Sequential()

# %%
cnn.add(Conv2D(32,(3,3), input_shape = (64,64,3), activation = 'relu'))
cnn.add(MaxPooling2D(pool_size = (2,2)))
cnn.add(Conv2D(32,(3,3), activation = 'relu'))
cnn.add(MaxPooling2D(pool_size = (2,2)))
cnn.add(Flatten())
# Out:
# C:\Users\Ajay\AppData\Roaming\Python\Python313\site-packages\keras\src\layers\convolutional\base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
cnn.add(Dense(64 ,activation = 'relu'))
cnn.add(Dense(32 ,activation = 'relu'))
cnn.add(Dense(16 ,activation = 'relu'))
cnn.add(Dense(8 ,activation = 'relu'))
cnn.add(Dense(4 ,activation = 'relu'))
cnn.add(Dense(1 ,activation = 'sigmoid'))

# %%
cnn.compile(loss = 'binary_crossentropy', optimizer = 'adam')
# Out:
# WARNING:tensorflow:TensorFlow GPU support is not available on native Windows for TensorFlow >= 2.11. Even if CUDA/cuDNN are installed, GPU will not be used. Please use WSL2 or the TensorFlow-DirectML plugin.

# %%
train_datagen = ImageDataGenerator(
        rescale=1./255,
        shear_range=0.2,
        zoom_range=0.2,
        horizontal_flip=True)

test_datagen = ImageDataGenerator(rescale=1./255)

train_generator = train_datagen.flow_from_directory(
        r"C:\Users\Ajay\OneDrive\Desktop\CRAFTEDGE DATASET\CNN\Cat Dog dataset Test and Train\Training_set",
        target_size=(64,64),
        batch_size=32,
        class_mode='binary')

test_generator = test_datagen.flow_from_directory(
        r"C:\Users\Ajay\OneDrive\Desktop\CRAFTEDGE DATASET\CNN\Cat Dog dataset Test and Train\Test_set",
        target_size=(64,64),
        batch_size=32,
        class_mode='binary')

cnn.fit(
        train_generator,
        steps_per_epoch=251,
        epochs=20,
        validation_data=test_generator)
# Out:
# Found 8005 images belonging to 2 classes.
# Found 2023 images belonging to 2 classes.
# Epoch 1/20
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 44s 167ms/step - loss: 0.6723 - val_loss: 0.6092
# Epoch 2/20
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 37s 148ms/step - loss: 0.6038 - val_loss: 0.6743
# Epoch 3/20
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 43s 170ms/step - loss: 0.5595 - val_loss: 0.5922
# Epoch 4/20
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 35s 141ms/step - loss: 0.5303 - val_loss: 0.5408
# Epoch 5/20
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 40s 137ms/step - loss: 0.5134 - val_loss: 0.5246
# Epoch 6/20
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 35s 140ms/step - loss: 0.4953 - val_loss: 0.4891
# Epoch 7/20
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 37s 146ms/step - loss: 0.4713 - val_loss: 0.5442
# Epoch 8/20
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 36s 144ms/step - loss: 0.4650 - val_loss: 0.4564
# Epoch 9/20
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 37s 146ms/step - loss: 0.4428 - val_loss: 0.4726
# Epoch 10/20
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 36s 142ms/step - loss: 0.4282 - val_loss: 0.4503
# Epoch 11/20
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 36s 145ms/step - loss: 0.4094 - val_loss: 0.4812
# Epoch 12/20
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 38s 151ms/step - loss: 0.4061 - val_loss: 0.4547
# Epoch 13/20
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 36s 142ms/step - loss: 0.3908 - val_loss: 0.4975
# Epoch 14/20
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 36s 142ms/step - loss: 0.3757 - val_loss: 0.4752
# Epoch 15/20
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 40s 138ms/step - loss: 0.3731 - val_loss: 0.4532
# Epoch 16/20
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 36s 144ms/step - loss: 0.3540 - val_loss: 0.4471
# Epoch 17/20
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 40s 138ms/step - loss: 0.3411 - val_loss: 0.5075
# Epoch 18/20
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 36s 145ms/step - loss: 0.3401 - val_loss: 0.5699
# Epoch 19/20
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 36s 144ms/step - loss: 0.3238 - val_loss: 0.5055
# Epoch 20/20
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 35s 139ms/step - loss: 0.3079 - val_loss: 0.4765

# %%
from keras.preprocessing import image
import numpy as np

# %%
img = image.load_img(r"C:\Users\Ajay\OneDrive\Desktop\CRAFTEDGE DATASET\CNN\Cat Dog dataset Test and Train\Training_set\dogs\dog.47.jpg",target_size=(64,64))

# %%
img = image.img_to_array(img)

# %%
img = img / 255.0

# %%
img = np.expand_dims(img, axis=0)

# %%
img = img / 255.0

# %%
result = cnn.predict(img)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step

# %%
if result[0][0]<0.5:
    print("CAT")
else:
    print("Dog")
# Out:
# CAT
